# %%
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt    #グラフ出力用module

BATCH_SIZE = 100
WEIGHT_DECAY = 0.005
LEARNING_RATE = 0.0001
EPOCH = 100
PATH = "C:\\Users\\administrator\\CNNtest"

transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor(),torchvision.transforms.Normalize((0.5,), (0.5,))])

trainset = torchvision.datasets.MNIST(root = PATH, train = True, download = True, transform = transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size = BATCH_SIZE,
                        shuffle = True, num_workers = 2)

testset = torchvision.datasets.MNIST(root = PATH, train = False, download = True, transform = transform)
testloader = torch.utils.data.DataLoader(testset, batch_size = BATCH_SIZE,
                        shuffle = False, num_workers = 2)

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.relu = nn.ReLU()
        self.pool = nn.MaxPool2d(2, stride=2)

        self.conv1 = nn.Conv2d(1,16,3)
        self.conv2 = nn.Conv2d(16,32,3)

        self.fc1 = nn.Linear(32 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 10)

    def forward(self, x):
        x = self.conv1(x)
        x = self.relu(x)
        x = self.pool(x)
        x = self.conv2(x)
        x = self.relu(x)
        x = self.pool(x)
        x = x.view(x.size()[0], -1)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x


device = torch.device("cuda:0")
net = Net()
net = net.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=LEARNING_RATE, momentum=0.9, weight_decay=WEIGHT_DECAY)

train_loss_value=[]      #trainingのlossを保持するlist
train_acc_value=[]       #trainingのaccuracyを保持するlist
test_loss_value=[]       #testのlossを保持するlist
test_acc_value=[]        #testのaccuracyを保持するlist 

for epoch in range(EPOCH):
    print('epoch', epoch+1)    #epoch数の出力
    for (inputs, labels) in trainloader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

    sum_loss = 0.0          #lossの合計
    sum_correct = 0         #正解率の合計
    sum_total = 0           #dataの数の合計

    #train dataを使ってテストをする(パラメータ更新がないようになっている)
    for (inputs, labels) in trainloader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        sum_loss += loss.item()                            #lossを足していく
        _, predicted = outputs.max(1)                      #出力の最大値の添字(予想位置)を取得
        sum_total += labels.size(0)                        #labelの数を足していくことでデータの総和を取る
        sum_correct += (predicted == labels).sum().item()  #予想位置と実際の正解を比べ,正解している数だけ足す
    print("train mean loss={}, accuracy={}"
            .format(sum_loss*BATCH_SIZE/len(trainloader.dataset), float(sum_correct/sum_total))) #lossとaccuracy出力
    train_loss_value.append(sum_loss*BATCH_SIZE/len(trainloader.dataset))  #traindataのlossをグラフ描画のためにlistに保持
    train_acc_value.append(float(sum_correct/sum_total))   #traindataのaccuracyをグラフ描画のためにlistに保持

    sum_loss = 0.0
    sum_correct = 0
    sum_total = 0

    #test dataを使ってテストをする
    for (inputs, labels) in testloader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        sum_loss += loss.item()
        _, predicted = outputs.max(1)
        sum_total += labels.size(0)
        sum_correct += (predicted == labels).sum().item()
    print("test  mean loss={}, accuracy={}"
            .format(sum_loss*BATCH_SIZE/len(testloader.dataset), float(sum_correct/sum_total)))
    test_loss_value.append(sum_loss*BATCH_SIZE/len(testloader.dataset))
    test_acc_value.append(float(sum_correct/sum_total))

plt.figure(figsize=(6,6))      #グラフ描画用

#以下グラフ描画
plt.plot(range(EPOCH), train_loss_value)
plt.plot(range(EPOCH), test_loss_value, c='#00ff00')
plt.xlim(0, EPOCH)
plt.ylim(0, 2.5)
plt.xlabel('EPOCH')
plt.ylabel('LOSS')
plt.legend(['train loss', 'test loss'])
plt.title('loss')
plt.savefig("loss_image.png")
plt.clf()

plt.plot(range(EPOCH), train_acc_value)
plt.plot(range(EPOCH), test_acc_value, c='#00ff00')
plt.xlim(0, EPOCH)
plt.ylim(0, 1)
plt.xlabel('EPOCH')
plt.ylabel('ACCURACY')
plt.legend(['train acc', 'test acc'])
plt.title('accuracy')
plt.savefig("accuracy_image.png")
# Out:
# epoch 1
# train mean loss=2.2717865816752116, accuracy=0.25748333333333334
# test  mean loss=2.2711802887916566, accuracy=0.265
# epoch 2
# train mean loss=2.2268558752536776, accuracy=0.5092666666666666
# test  mean loss=2.2250664114952086, accuracy=0.5211
# epoch 3
# train mean loss=2.1409293591976164, accuracy=0.6042666666666666
# test  mean loss=2.137463834285736, accuracy=0.6142
# epoch 4
# train mean loss=1.9479701954126358, accuracy=0.6427166666666667
# test  mean loss=1.941026233434677, accuracy=0.6551
# epoch 5
# train mean loss=1.5159264918168385, accuracy=0.7236666666666667
# test  mean loss=1.5014541065692901, accuracy=0.7389
# epoch 6
# train mean loss=0.973985844651858, accuracy=0.7987833333333333
# test  mean loss=0.9524833750724793, accuracy=0.8096
# epoch 7
# train mean loss=0.6746343939006328, accuracy=0.8402666666666667
# test  mean loss=0.6534766587615013, accuracy=0.8511
# epoch 8
# train mean loss=0.5363863701124986, accuracy=0.8624333333333334
# test  mean loss=0.5162734872102738, accuracy=0.8682
# epoch 9
# train mean loss=0.46079524730642635, accuracy=0.8757833333333334
# test  mean loss=0.44128806963562967, accuracy=0.8798
# epoch 10
# train mean loss=0.41341794063647586, accuracy=0.8852
# test  mean loss=0.39436162941157815, accuracy=0.8902
# epoch 11
# train mean loss=0.3795103092988332, accuracy=0.89325
# test  mean loss=0.36094188831746576, accuracy=0.899
# epoch 12
# train mean loss=0.35404629188279313, accuracy=0.8994333333333333
# test  mean loss=0.3354112817719579, accuracy=0.9041
# epoch 13
# train mean loss=0.3335050851851702, accuracy=0.9048666666666667
# test  mean loss=0.31507820304483175, accuracy=0.9093
# epoch 14
# train mean loss=0.31649193229774636, accuracy=0.9095833333333333
# test  mean loss=0.2991998289525509, accuracy=0.914
# epoch 15
# train mean loss=0.30181185372173785, accuracy=0.9139333333333334
# test  mean loss=0.28370599446818234, accuracy=0.9181
# epoch 16
# train mean loss=0.2881318631519874, accuracy=0.91695
# test  mean loss=0.2703924839943647, accuracy=0.9212
# epoch 17
# train mean loss=0.2757320848107338, accuracy=0.9206
# test  mean loss=0.2575801306776702, accuracy=0.925
# epoch 18
# train mean loss=0.2649260341003537, accuracy=0.92385
# test  mean loss=0.2477885953336954, accuracy=0.928
# epoch 19
# train mean loss=0.2550529952843984, accuracy=0.9265833333333333
# test  mean loss=0.23747808447107674, accuracy=0.9313
# epoch 20
# train mean loss=0.24566389940679073, accuracy=0.9290833333333334
# test  mean loss=0.22829961279407143, accuracy=0.9339
# epoch 21
# train mean loss=0.23717470572640498, accuracy=0.93155
# test  mean loss=0.2197013366036117, accuracy=0.9366
# epoch 22
# train mean loss=0.22867330143849054, accuracy=0.9340166666666667
# test  mean loss=0.212531729741022, accuracy=0.9381
# epoch 23
# train mean loss=0.2211032082264622, accuracy=0.9357833333333333
# test  mean loss=0.2040485755726695, accuracy=0.9416
# epoch 24
# train mean loss=0.2142713418851296, accuracy=0.93815
# test  mean loss=0.19786873132921756, accuracy=0.9431
# epoch 25
# train mean loss=0.20784669782966375, accuracy=0.9400333333333334
# test  mean loss=0.19148789851926268, accuracy=0.9455
# epoch 26
# train mean loss=0.2008659418299794, accuracy=0.9426833333333333
# test  mean loss=0.18508319972082973, accuracy=0.9471
# epoch 27
# train mean loss=0.19503936000168323, accuracy=0.94435
# test  mean loss=0.17967469327151775, accuracy=0.9485
# epoch 28
# train mean loss=0.1893099086234967, accuracy=0.9460166666666666
# test  mean loss=0.17368328374810516, accuracy=0.9512
# epoch 29
# train mean loss=0.1841222456159691, accuracy=0.9474
# test  mean loss=0.16892870171926916, accuracy=0.9531
# epoch 30
# train mean loss=0.17928457946827014, accuracy=0.94845
# test  mean loss=0.1641822877060622, accuracy=0.9536
# epoch 31
# train mean loss=0.17497660190487901, accuracy=0.95045
# test  mean loss=0.16097582019865514, accuracy=0.9546
# epoch 32
# train mean loss=0.17030800126492976, accuracy=0.9513166666666667
# test  mean loss=0.15525525811128318, accuracy=0.9565
# epoch 33
# train mean loss=0.16633965784683824, accuracy=0.9532
# test  mean loss=0.15257444886490704, accuracy=0.9578
# epoch 34
# train mean loss=0.16261926855891942, accuracy=0.9534666666666667
# test  mean loss=0.14743355482816697, accuracy=0.9593
# epoch 35
# train mean loss=0.1584783880971372, accuracy=0.9549166666666666
# test  mean loss=0.14421918660402297, accuracy=0.9599
# epoch 36
# train mean loss=0.15495429762328664, accuracy=0.9560333333333333
# test  mean loss=0.14072842785157264, accuracy=0.9605
# epoch 37
# train mean loss=0.15179283322145543, accuracy=0.95675
# test  mean loss=0.1380204142536968, accuracy=0.962
# epoch 38
# train mean loss=0.14885448795432846, accuracy=0.9578166666666666
# test  mean loss=0.13535222578328102, accuracy=0.9623
# epoch 39
# train mean loss=0.14591454590360323, accuracy=0.9585
# test  mean loss=0.13238436568994075, accuracy=0.9631
# epoch 40
# train mean loss=0.14330907280246416, accuracy=0.9594
# test  mean loss=0.13035584019497037, accuracy=0.9647
# epoch 41
# train mean loss=0.14026099694892763, accuracy=0.9603333333333334
# test  mean loss=0.12729415812995284, accuracy=0.9651
# epoch 42
# train mean loss=0.13803032213201125, accuracy=0.9605666666666667
# test  mean loss=0.12464024184737355, accuracy=0.9659
# epoch 43
# train mean loss=0.13507996707533795, accuracy=0.96135
# test  mean loss=0.12188392106443643, accuracy=0.9663
# epoch 44
# train mean loss=0.13336080613856513, accuracy=0.9620666666666666
# test  mean loss=0.12065677722916007, accuracy=0.9663
# epoch 45
# train mean loss=0.13105673930297296, accuracy=0.9627333333333333
# test  mean loss=0.11738150429911912, accuracy=0.9683
# epoch 46
# train mean loss=0.12898667313779394, accuracy=0.9634666666666667
# test  mean loss=0.11662432005163283, accuracy=0.9672
# epoch 47
# train mean loss=0.12659092575932543, accuracy=0.9643166666666667
# test  mean loss=0.11397490710020065, accuracy=0.9683
# epoch 48
# train mean loss=0.12493660484751065, accuracy=0.9644166666666667
# test  mean loss=0.1120924493484199, accuracy=0.9683
# epoch 49
# train mean loss=0.12295870299761494, accuracy=0.9648166666666667
# test  mean loss=0.11047539658844471, accuracy=0.9694
# epoch 50
# train mean loss=0.12166155856102705, accuracy=0.9657666666666667
# test  mean loss=0.1092602218594402, accuracy=0.9697
# epoch 51
# train mean loss=0.11935212420920531, accuracy=0.9663666666666667
# test  mean loss=0.107301976387389, accuracy=0.9702
# epoch 52
# train mean loss=0.11819363389785091, accuracy=0.9663
# test  mean loss=0.10558992931153625, accuracy=0.9706
# epoch 53
# train mean loss=0.11640974989160896, accuracy=0.9670666666666666
# test  mean loss=0.10433091471437365, accuracy=0.9711
# epoch 54
# train mean loss=0.11502780806273222, accuracy=0.96725
# test  mean loss=0.10323752017691731, accuracy=0.971
# epoch 55
# train mean loss=0.11324888267864784, accuracy=0.9678666666666667
# test  mean loss=0.10151357244700193, accuracy=0.9718
# epoch 56
# train mean loss=0.1121667844026039, accuracy=0.9682666666666667
# test  mean loss=0.10092309165745973, accuracy=0.9716
# epoch 57
# train mean loss=0.11066716038621963, accuracy=0.96845
# test  mean loss=0.0986165964603424, accuracy=0.9723
# epoch 58
# train mean loss=0.10937314043442409, accuracy=0.9692166666666666
# test  mean loss=0.09865753132849932, accuracy=0.9718
# epoch 59
# train mean loss=0.10812794699644049, accuracy=0.9693333333333334
# test  mean loss=0.0968120400654152, accuracy=0.9721
# epoch 60
# train mean loss=0.1068518875601391, accuracy=0.9698
# test  mean loss=0.09568028181325644, accuracy=0.9729
# epoch 61
# train mean loss=0.10592174196926256, accuracy=0.97015
# test  mean loss=0.09521719700656832, accuracy=0.9733
# epoch 62
# train mean loss=0.10496820200855533, accuracy=0.9704166666666667
# test  mean loss=0.09426212095888331, accuracy=0.9736
# epoch 63
# train mean loss=0.10409618665153782, accuracy=0.97035
# test  mean loss=0.09206806694157421, accuracy=0.9735
# epoch 64
# train mean loss=0.10298178703213731, accuracy=0.97065
# test  mean loss=0.09198885501828044, accuracy=0.974
# epoch 65
# train mean loss=0.101726178539296, accuracy=0.97135
# test  mean loss=0.0905956185166724, accuracy=0.9749
# epoch 66
# train mean loss=0.10141246127275129, accuracy=0.9710333333333333
# test  mean loss=0.09045510809635743, accuracy=0.9742
# epoch 67
# train mean loss=0.10009348857216536, accuracy=0.9719833333333333
# test  mean loss=0.0895448138215579, accuracy=0.9743
# epoch 68
# train mean loss=0.09900650262832641, accuracy=0.9718666666666667
# test  mean loss=0.08800871101208031, accuracy=0.975
# epoch 69
# train mean loss=0.09816042670048773, accuracy=0.9724
# test  mean loss=0.08778382971184329, accuracy=0.9755
# epoch 70
# train mean loss=0.09761958750896156, accuracy=0.97255
# test  mean loss=0.0873390414332971, accuracy=0.9748
# epoch 71
# train mean loss=0.09654843266432483, accuracy=0.9726833333333333
# test  mean loss=0.08608924221945927, accuracy=0.9749
# epoch 72
# train mean loss=0.09570198568205039, accuracy=0.9731333333333333
# test  mean loss=0.08526023256825283, accuracy=0.9755
# epoch 73
# train mean loss=0.0953277642497172, accuracy=0.9729
# test  mean loss=0.08504375219345092, accuracy=0.9758
# epoch 74
# train mean loss=0.09448382336025436, accuracy=0.97325
# test  mean loss=0.08389450697926805, accuracy=0.9762
# epoch 75
# train mean loss=0.09371428409901758, accuracy=0.9736166666666667
# test  mean loss=0.08436194281326607, accuracy=0.9753
# epoch 76
# train mean loss=0.09302764588966966, accuracy=0.9735833333333334
# test  mean loss=0.08275917617138476, accuracy=0.9763
# epoch 77
# train mean loss=0.09234211694759627, accuracy=0.97395
# test  mean loss=0.0824117728904821, accuracy=0.9762
# epoch 78
# train mean loss=0.0913962201277415, accuracy=0.9742166666666666
# test  mean loss=0.08203817834611982, accuracy=0.9758
# epoch 79
# train mean loss=0.09078509150072932, accuracy=0.9742166666666666
# test  mean loss=0.08110699979122728, accuracy=0.9764
# epoch 80
# train mean loss=0.09013827604862551, accuracy=0.97445
# test  mean loss=0.08074722565244884, accuracy=0.9765
# epoch 81
# train mean loss=0.08948377851086359, accuracy=0.9747333333333333
# test  mean loss=0.08011841917410494, accuracy=0.9768
# epoch 82
# train mean loss=0.08900030931768318, accuracy=0.9748666666666667
# test  mean loss=0.07932902106782422, accuracy=0.9774
# epoch 83
# train mean loss=0.08838748550663392, accuracy=0.9751333333333333
# test  mean loss=0.07900864076800644, accuracy=0.9773
# epoch 84
# train mean loss=0.08778688142697016, accuracy=0.9752333333333333
# test  mean loss=0.07805917950347066, accuracy=0.9774
# epoch 85
# train mean loss=0.08716923143404226, accuracy=0.9752
# test  mean loss=0.07764374964637683, accuracy=0.9781
# epoch 86
# train mean loss=0.08657997647610803, accuracy=0.9755833333333334
# test  mean loss=0.07764817507006228, accuracy=0.9772
# epoch 87
# train mean loss=0.08664566439266007, accuracy=0.9755666666666667
# test  mean loss=0.0773450492694974, accuracy=0.9778
# epoch 88
# train mean loss=0.08543486102173725, accuracy=0.9758666666666667
# test  mean loss=0.07636893925722689, accuracy=0.9778
# epoch 89
# train mean loss=0.08521311936589579, accuracy=0.9760166666666666
# test  mean loss=0.07618403987493366, accuracy=0.9783
# epoch 90
# train mean loss=0.08471343263983727, accuracy=0.9761666666666666
# test  mean loss=0.07575406244955957, accuracy=0.9784
# epoch 91
# train mean loss=0.08413394544273615, accuracy=0.9762166666666666
# test  mean loss=0.07557912567630411, accuracy=0.9776
# epoch 92
# train mean loss=0.08364734411860505, accuracy=0.9765166666666667
# test  mean loss=0.07517015878343955, accuracy=0.9776
# epoch 93
# train mean loss=0.08349474699236453, accuracy=0.9762666666666666
# test  mean loss=0.07437762200366706, accuracy=0.9784
# epoch 94
# train mean loss=0.08263421922301252, accuracy=0.9769166666666667
# test  mean loss=0.07396520347800106, accuracy=0.9787
# epoch 95
# train mean loss=0.082298527409633, accuracy=0.97695
# test  mean loss=0.07383290505502373, accuracy=0.9786
# epoch 96
# train mean loss=0.08201410659278432, accuracy=0.9768166666666667
# test  mean loss=0.07315569946309551, accuracy=0.9787
# epoch 97
# train mean loss=0.0813853039778769, accuracy=0.9774166666666667
# test  mean loss=0.07275996672920883, accuracy=0.9791
# epoch 98
# train mean loss=0.08089594468163948, accuracy=0.9775333333333334
# test  mean loss=0.07261502285022288, accuracy=0.9793
# epoch 99
# train mean loss=0.08053437497311582, accuracy=0.9774666666666667
# test  mean loss=0.07211656529456377, accuracy=0.9788
# epoch 100
# train mean loss=0.08014113523376484, accuracy=0.9776833333333333
# test  mean loss=0.07189452136866749, accuracy=0.9792
